# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from torch.utils.data import random_split, DataLoader
import os

from corner_dataset import CornersDatasetOrdered, CornersDatasetTopToBottom
from corner_detector_linear import CornerDetectorLinear

# %%
from torch.utils.data import random_split

img_dir = "images"
corners_dir = "corners"

full_dataset = CornersDatasetOrdered(
    img_dir=img_dir,
    corners_dir=corners_dir
)

val_ratio = 0.2
val_size = int(len(full_dataset) * val_ratio)
train_size = len(full_dataset) - val_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])


train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(len(train_dataset))
print(len(val_dataset))

# %%
from torch.utils.data import random_split

img_dir = "images"
corners_dir = "corners"

full_dataset = CornersDatasetTopToBottom(
    img_dir=img_dir,
    corners_dir=corners_dir
)

val_ratio = 0.2
val_size = int(len(full_dataset) * val_ratio)
train_size = len(full_dataset) - val_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])


train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=16,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

print(len(train_dataset))
print(len(val_dataset))
# Out:
# 809
# 202

# %%
def train(
        train_loader,
        val_loader,
        model,
        num_epochs=30,
        lr=1e-3,
        save_path="corner_detector.pth",
        load_path=None,
):
    save_path = os.path.join("models", save_path)
    os.makedirs("models", exist_ok=True)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    if load_path is not None:
        load_path = os.path.join("models", load_path)
        model.load_state_dict(torch.load(load_path))

    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val_loss = float("inf")

    for epoch in range(1, num_epochs + 1):
        model.train()
        running_loss = 0.0

        for images, targets in train_loader:
            images = images.to(device)
            targets = targets.to(device)

            preds = model(images)

            loss = criterion(preds, targets)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)

        if val_loader is not None:
            model.eval()
            val_running_loss = 0.0

            with torch.no_grad():
                for images, targets in val_loader:
                    images = images.to(device)
                    targets = targets.to(device)

                    preds = model(images)

                    loss = criterion(preds, targets)
                    val_running_loss += loss.item() * images.size(0)

            epoch_val_loss = val_running_loss / len(val_loader.dataset)

            if epoch_val_loss < best_val_loss:
                best_val_loss = epoch_val_loss
                torch.save(model.state_dict(), save_path)

            print(
                f"Epoch [{epoch}/{num_epochs}] "
                f"Train Loss: {epoch_train_loss:.6f}  "
                f"Val Loss: {epoch_val_loss:.6f}"
            )
        else:
            print(
                f"Epoch [{epoch}/{num_epochs}] "
                f"Train Loss: {epoch_train_loss:.6f}"
            )

    if val_loader is None:
        torch.save(model.state_dict(), save_path)

    print("Training finished. Best model saved to:", save_path)
    return model

# %%
model = CornerDetectorLinear()

# %%
trained_model = train(
    train_loader=train_loader,
    val_loader=val_loader,
    model=model,
    num_epochs=80,
    lr=1e-3,
    save_path="corner_detector_v2_test1.pth"
)
# Out:
# Epoch [1/80] Train Loss: 0.160313  Val Loss: 2.719723
# Epoch [2/80] Train Loss: 0.009574  Val Loss: 0.007714
# Epoch [3/80] Train Loss: 0.005255  Val Loss: 0.004241
# Epoch [4/80] Train Loss: 0.005945  Val Loss: 0.006333
# Epoch [5/80] Train Loss: 0.004123  Val Loss: 0.002225
# Epoch [6/80] Train Loss: 0.003779  Val Loss: 0.002057
# Epoch [7/80] Train Loss: 0.002722  Val Loss: 0.002009
# Epoch [8/80] Train Loss: 0.002644  Val Loss: 0.001698
# Epoch [9/80] Train Loss: 0.001767  Val Loss: 0.001286
# Epoch [10/80] Train Loss: 0.002101  Val Loss: 0.002311
# Epoch [11/80] Train Loss: 0.002572  Val Loss: 0.001643
# Epoch [12/80] Train Loss: 0.002206  Val Loss: 0.001976
# Epoch [13/80] Train Loss: 0.002412  Val Loss: 0.001754
# Epoch [14/80] Train Loss: 0.002644  Val Loss: 0.001343
# Epoch [15/80] Train Loss: 0.001888  Val Loss: 0.002148
# Epoch [16/80] Train Loss: 0.002200  Val Loss: 0.002099
# Epoch [17/80] Train Loss: 0.001722  Val Loss: 0.001113
# Epoch [18/80] Train Loss: 0.001377  Val Loss: 0.001607
# Epoch [19/80] Train Loss: 0.001266  Val Loss: 0.001247
# Epoch [20/80] Train Loss: 0.001568  Val Loss: 0.002282
# Epoch [21/80] Train Loss: 0.001687  Val Loss: 0.001095
# Epoch [22/80] Train Loss: 0.001543  Val Loss: 0.001407
# Epoch [23/80] Train Loss: 0.001067  Val Loss: 0.000910
# Epoch [24/80] Train Loss: 0.001603  Val Loss: 0.001469
# Epoch [25/80] Train Loss: 0.001190  Val Loss: 0.001025
# Epoch [26/80] Train Loss: 0.001404  Val Loss: 0.001856
# Epoch [27/80] Train Loss: 0.001331  Val Loss: 0.001376
# Epoch [28/80] Train Loss: 0.001994  Val Loss: 0.001086
# Epoch [29/80] Train Loss: 0.002022  Val Loss: 0.001685
# Epoch [30/80] Train Loss: 0.001582  Val Loss: 0.001505
# Epoch [31/80] Train Loss: 0.001113  Val Loss: 0.001005
# Epoch [32/80] Train Loss: 0.001731  Val Loss: 0.001253
# Epoch [33/80] Train Loss: 0.001328  Val Loss: 0.001909
# Epoch [34/80] Train Loss: 0.001776  Val Loss: 0.001464
# Epoch [35/80] Train Loss: 0.002440  Val Loss: 0.001306
# Epoch [36/80] Train Loss: 0.001625  Val Loss: 0.001481
# Epoch [37/80] Train Loss: 0.002867  Val Loss: 0.003341
# Epoch [38/80] Train Loss: 0.001753  Val Loss: 0.001208
# Epoch [39/80] Train Loss: 0.001259  Val Loss: 0.000743
# Epoch [40/80] Train Loss: 0.001719  Val Loss: 0.001424
# Epoch [41/80] Train Loss: 0.001445  Val Loss: 0.002078
# Epoch [42/80] Train Loss: 0.001542  Val Loss: 0.000803
# Epoch [43/80] Train Loss: 0.000924  Val Loss: 0.000965
# Epoch [44/80] Train Loss: 0.001059  Val Loss: 0.001564
# Epoch [45/80] Train Loss: 0.000855  Val Loss: 0.000988
# Epoch [46/80] Train Loss: 0.000884  Val Loss: 0.001175
# Epoch [47/80] Train Loss: 0.001175  Val Loss: 0.001046
# Epoch [48/80] Train Loss: 0.001356  Val Loss: 0.000899
# Epoch [49/80] Train Loss: 0.000970  Val Loss: 0.001075
# Epoch [50/80] Train Loss: 0.000860  Val Loss: 0.000824
# Epoch [51/80] Train Loss: 0.000789  Val Loss: 0.001666
# Epoch [52/80] Train Loss: 0.001541  Val Loss: 0.002456
# Epoch [53/80] Train Loss: 0.001450  Val Loss: 0.002479
# Epoch [54/80] Train Loss: 0.001072  Val Loss: 0.000631
# Epoch [55/80] Train Loss: 0.001262  Val Loss: 0.000662
# Epoch [56/80] Train Loss: 0.001339  Val Loss: 0.000656
# Epoch [57/80] Train Loss: 0.000758  Val Loss: 0.001554
# Epoch [58/80] Train Loss: 0.001448  Val Loss: 0.001501
# Epoch [59/80] Train Loss: 0.001495  Val Loss: 0.001988
# Epoch [60/80] Train Loss: 0.001750  Val Loss: 0.001046
# Epoch [61/80] Train Loss: 0.001228  Val Loss: 0.000619
# Epoch [62/80] Train Loss: 0.001038  Val Loss: 0.001179
# Epoch [63/80] Train Loss: 0.001002  Val Loss: 0.000936
# Epoch [64/80] Train Loss: 0.000881  Val Loss: 0.000943
# Epoch [65/80] Train Loss: 0.000908  Val Loss: 0.000553
# Epoch [66/80] Train Loss: 0.000548  Val Loss: 0.000924
# Epoch [67/80] Train Loss: 0.000631  Val Loss: 0.000758
# Epoch [68/80] Train Loss: 0.000661  Val Loss: 0.000814
# Epoch [69/80] Train Loss: 0.000711  Val Loss: 0.001881
# Epoch [70/80] Train Loss: 0.001264  Val Loss: 0.001987
# Epoch [71/80] Train Loss: 0.001112  Val Loss: 0.001694
# Epoch [72/80] Train Loss: 0.001170  Val Loss: 0.001592
# Epoch [73/80] Train Loss: 0.001262  Val Loss: 0.000949
# Epoch [74/80] Train Loss: 0.001080  Val Loss: 0.001023
# Epoch [75/80] Train Loss: 0.000623  Val Loss: 0.000828
# Epoch [76/80] Train Loss: 0.000695  Val Loss: 0.000907
# Epoch [77/80] Train Loss: 0.000924  Val Loss: 0.001167
# Epoch [78/80] Train Loss: 0.000626  Val Loss: 0.000505
# Epoch [79/80] Train Loss: 0.000469  Val Loss: 0.000556
# Epoch [80/80] Train Loss: 0.000624  Val Loss: 0.001120
# Training finished. Best model saved to: models/corner_detector_v2_test1.pth

# %%
trained_model_2 = train(
    train_loader=train_loader,
    val_loader=val_loader,
    model=model,
    num_epochs=150,
    lr=1e-3,
    save_path="corner_detector_test2.pth",
    load_path="corner_detector_test1.pth"
)
# Out:
# Epoch [1/150] Train Loss: 0.127071  Val Loss: 1.026602
# Epoch [2/150] Train Loss: 0.040275  Val Loss: 0.175476
# Epoch [3/150] Train Loss: 0.028663  Val Loss: 0.073614
# Epoch [4/150] Train Loss: 0.029833  Val Loss: 0.031058
# Epoch [5/150] Train Loss: 0.018874  Val Loss: 0.025015
# Epoch [6/150] Train Loss: 0.018892  Val Loss: 0.019912
# Epoch [7/150] Train Loss: 0.015256  Val Loss: 0.028113
# Epoch [8/150] Train Loss: 0.024035  Val Loss: 0.031479
# Epoch [9/150] Train Loss: 0.024366  Val Loss: 0.032811
# Epoch [10/150] Train Loss: 0.016035  Val Loss: 0.020938
# Epoch [11/150] Train Loss: 0.010917  Val Loss: 0.013739
# Epoch [12/150] Train Loss: 0.012027  Val Loss: 0.020989
# Epoch [13/150] Train Loss: 0.008744  Val Loss: 0.014401
# Epoch [14/150] Train Loss: 0.023727  Val Loss: 0.020170
# Epoch [15/150] Train Loss: 0.008111  Val Loss: 0.016971
# Epoch [16/150] Train Loss: 0.006731  Val Loss: 0.017878
# Epoch [17/150] Train Loss: 0.011061  Val Loss: 0.013041
# Epoch [18/150] Train Loss: 0.006097  Val Loss: 0.017885
# Epoch [19/150] Train Loss: 0.005590  Val Loss: 0.016551
# Epoch [20/150] Train Loss: 0.008311  Val Loss: 0.018474
# Epoch [21/150] Train Loss: 0.012057  Val Loss: 0.014841
# Epoch [22/150] Train Loss: 0.014501  Val Loss: 0.017751
# Epoch [23/150] Train Loss: 0.006300  Val Loss: 0.011760
# Epoch [24/150] Train Loss: 0.006909  Val Loss: 0.013754
# Epoch [25/150] Train Loss: 0.005069  Val Loss: 0.012570
# Epoch [26/150] Train Loss: 0.005575  Val Loss: 0.010992
# Epoch [27/150] Train Loss: 0.004650  Val Loss: 0.012565
# Epoch [28/150] Train Loss: 0.004893  Val Loss: 0.014438
# Epoch [29/150] Train Loss: 0.005216  Val Loss: 0.011452
# Epoch [30/150] Train Loss: 0.004252  Val Loss: 0.012598
# Epoch [31/150] Train Loss: 0.005785  Val Loss: 0.011716
# Epoch [32/150] Train Loss: 0.003314  Val Loss: 0.012447
# Epoch [33/150] Train Loss: 0.004136  Val Loss: 0.014379
# Epoch [34/150] Train Loss: 0.007595  Val Loss: 0.015917
# Epoch [35/150] Train Loss: 0.004641  Val Loss: 0.013260
# Epoch [36/150] Train Loss: 0.003468  Val Loss: 0.011695
# Epoch [37/150] Train Loss: 0.002214  Val Loss: 0.010990
# Epoch [38/150] Train Loss: 0.003279  Val Loss: 0.014922
# Epoch [39/150] Train Loss: 0.007388  Val Loss: 0.011739
# Epoch [40/150] Train Loss: 0.004779  Val Loss: 0.012551
# Epoch [41/150] Train Loss: 0.004291  Val Loss: 0.015638
# Epoch [42/150] Train Loss: 0.009068  Val Loss: 0.031568
# Epoch [43/150] Train Loss: 0.013354  Val Loss: 0.048247
# Epoch [44/150] Train Loss: 0.014161  Val Loss: 0.023101
# Epoch [45/150] Train Loss: 0.010044  Val Loss: 0.027582
# Epoch [46/150] Train Loss: 0.008126  Val Loss: 0.012336
# Epoch [47/150] Train Loss: 0.005618  Val Loss: 0.014144
# Epoch [48/150] Train Loss: 0.003767  Val Loss: 0.011303
# Epoch [49/150] Train Loss: 0.003561  Val Loss: 0.009855
# Epoch [50/150] Train Loss: 0.003098  Val Loss: 0.010329
# Epoch [51/150] Train Loss: 0.002751  Val Loss: 0.013937
# Epoch [52/150] Train Loss: 0.004477  Val Loss: 0.010692
# Epoch [53/150] Train Loss: 0.005157  Val Loss: 0.015754
# Epoch [54/150] Train Loss: 0.003801  Val Loss: 0.015110
# Epoch [55/150] Train Loss: 0.004565  Val Loss: 0.017029
# Epoch [56/150] Train Loss: 0.004352  Val Loss: 0.015780
# Epoch [57/150] Train Loss: 0.005285  Val Loss: 0.008915
# Epoch [58/150] Train Loss: 0.002740  Val Loss: 0.008765
# Epoch [59/150] Train Loss: 0.002623  Val Loss: 0.008617
# Epoch [60/150] Train Loss: 0.002592  Val Loss: 0.008772
# Epoch [61/150] Train Loss: 0.002449  Val Loss: 0.008394
# Epoch [62/150] Train Loss: 0.001660  Val Loss: 0.008665
# Epoch [63/150] Train Loss: 0.001353  Val Loss: 0.012961
# Epoch [64/150] Train Loss: 0.001966  Val Loss: 0.011208
# Epoch [65/150] Train Loss: 0.002797  Val Loss: 0.014816
# Epoch [66/150] Train Loss: 0.005114  Val Loss: 0.016043
# Epoch [67/150] Train Loss: 0.002775  Val Loss: 0.011222
# Epoch [68/150] Train Loss: 0.003110  Val Loss: 0.008231
# Epoch [69/150] Train Loss: 0.002857  Val Loss: 0.009776
# Epoch [70/150] Train Loss: 0.002402  Val Loss: 0.012489
# Epoch [71/150] Train Loss: 0.001505  Val Loss: 0.010784
# Epoch [72/150] Train Loss: 0.001817  Val Loss: 0.012715
# Epoch [73/150] Train Loss: 0.001919  Val Loss: 0.013419
# Epoch [74/150] Train Loss: 0.001177  Val Loss: 0.011282
# Epoch [75/150] Train Loss: 0.001186  Val Loss: 0.010517
# Epoch [76/150] Train Loss: 0.001082  Val Loss: 0.009920
# Epoch [77/150] Train Loss: 0.001499  Val Loss: 0.011425
# Epoch [78/150] Train Loss: 0.001230  Val Loss: 0.011208
# Epoch [79/150] Train Loss: 0.001570  Val Loss: 0.009927
# Epoch [80/150] Train Loss: 0.001006  Val Loss: 0.009855
# Epoch [81/150] Train Loss: 0.001251  Val Loss: 0.009968
# Epoch [82/150] Train Loss: 0.000977  Val Loss: 0.008868
# Epoch [83/150] Train Loss: 0.000965  Val Loss: 0.008916
# Epoch [84/150] Train Loss: 0.001019  Val Loss: 0.009213
# Epoch [85/150] Train Loss: 0.000723  Val Loss: 0.008797
# Epoch [86/150] Train Loss: 0.000795  Val Loss: 0.008415
# Epoch [87/150] Train Loss: 0.001052  Val Loss: 0.009249
# Epoch [88/150] Train Loss: 0.000939  Val Loss: 0.009238
# Epoch [89/150] Train Loss: 0.000951  Val Loss: 0.008076
# Epoch [90/150] Train Loss: 0.000776  Val Loss: 0.008001
# Epoch [91/150] Train Loss: 0.000665  Val Loss: 0.007739
# Epoch [92/150] Train Loss: 0.000615  Val Loss: 0.008957
# Epoch [93/150] Train Loss: 0.000756  Val Loss: 0.009049
# Epoch [94/150] Train Loss: 0.000695  Val Loss: 0.009074
# Epoch [95/150] Train Loss: 0.000824  Val Loss: 0.008648
# Epoch [96/150] Train Loss: 0.000783  Val Loss: 0.008737
# Epoch [97/150] Train Loss: 0.000706  Val Loss: 0.008823
# Epoch [98/150] Train Loss: 0.000946  Val Loss: 0.008931
# Epoch [99/150] Train Loss: 0.000970  Val Loss: 0.009474
# Epoch [100/150] Train Loss: 0.001008  Val Loss: 0.009226
# Epoch [101/150] Train Loss: 0.000890  Val Loss: 0.008837
# Epoch [102/150] Train Loss: 0.001059  Val Loss: 0.011068
# Epoch [103/150] Train Loss: 0.000918  Val Loss: 0.010610
# Epoch [104/150] Train Loss: 0.000769  Val Loss: 0.010152
# Epoch [105/150] Train Loss: 0.000723  Val Loss: 0.009960
# Epoch [106/150] Train Loss: 0.000586  Val Loss: 0.009258
# Epoch [107/150] Train Loss: 0.000654  Val Loss: 0.008926
# Epoch [108/150] Train Loss: 0.000588  Val Loss: 0.009208
# Epoch [109/150] Train Loss: 0.000719  Val Loss: 0.009474
# Epoch [110/150] Train Loss: 0.000730  Val Loss: 0.010026
# Epoch [111/150] Train Loss: 0.000598  Val Loss: 0.009679
# Epoch [112/150] Train Loss: 0.000485  Val Loss: 0.009378
# Epoch [113/150] Train Loss: 0.000711  Val Loss: 0.010167
# Epoch [114/150] Train Loss: 0.000576  Val Loss: 0.010602
# Epoch [115/150] Train Loss: 0.000726  Val Loss: 0.010252
# Epoch [116/150] Train Loss: 0.000766  Val Loss: 0.009933
# Epoch [117/150] Train Loss: 0.000616  Val Loss: 0.009251
# Epoch [118/150] Train Loss: 0.000542  Val Loss: 0.009504
# Epoch [119/150] Train Loss: 0.001287  Val Loss: 0.013869
# Epoch [120/150] Train Loss: 0.005163  Val Loss: 0.014530
# Epoch [121/150] Train Loss: 0.003403  Val Loss: 0.016950
# Epoch [122/150] Train Loss: 0.003438  Val Loss: 0.018781
# Epoch [123/150] Train Loss: 0.003369  Val Loss: 0.014590
# Epoch [124/150] Train Loss: 0.002288  Val Loss: 0.022413
# Epoch [125/150] Train Loss: 0.002823  Val Loss: 0.029023
# Epoch [126/150] Train Loss: 0.002383  Val Loss: 0.050913
# Epoch [127/150] Train Loss: 0.003916  Val Loss: 0.012719
# Epoch [128/150] Train Loss: 0.002766  Val Loss: 0.013195
# Epoch [129/150] Train Loss: 0.002543  Val Loss: 0.015317
# Epoch [130/150] Train Loss: 0.005134  Val Loss: 0.013993
# Epoch [131/150] Train Loss: 0.006854  Val Loss: 0.030765
# Epoch [132/150] Train Loss: 0.005890  Val Loss: 0.016779
# Epoch [133/150] Train Loss: 0.005783  Val Loss: 0.012084
# Epoch [134/150] Train Loss: 0.003582  Val Loss: 0.012637
# Epoch [135/150] Train Loss: 0.002790  Val Loss: 0.013650
# Epoch [136/150] Train Loss: 0.002510  Val Loss: 0.011988
# Epoch [137/150] Train Loss: 0.003301  Val Loss: 0.012052
# Epoch [138/150] Train Loss: 0.003015  Val Loss: 0.013539
# Epoch [139/150] Train Loss: 0.001619  Val Loss: 0.010668
# Epoch [140/150] Train Loss: 0.001254  Val Loss: 0.009717
# Epoch [141/150] Train Loss: 0.001158  Val Loss: 0.009109
# Epoch [142/150] Train Loss: 0.000960  Val Loss: 0.009324
# Epoch [143/150] Train Loss: 0.001164  Val Loss: 0.009043
# Epoch [144/150] Train Loss: 0.001011  Val Loss: 0.008896
# Epoch [145/150] Train Loss: 0.000942  Val Loss: 0.008766
# Epoch [146/150] Train Loss: 0.001410  Val Loss: 0.009365
# Epoch [147/150] Train Loss: 0.001262  Val Loss: 0.009458
# Epoch [148/150] Train Loss: 0.001051  Val Loss: 0.009177
# Epoch [149/150] Train Loss: 0.000913  Val Loss: 0.009106
# Epoch [150/150] Train Loss: 0.001078  Val Loss: 0.008881
# Training finished. Best model saved to: models/corner_detector_test2.pth
